# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
PATH_HISTORY = 'logs/training_history_2023-06-19_03:10:37.csv'

# %%
df_his = pd.read_csv(PATH_HISTORY)
df_his
# Out:
#     epoch  train_obj_loss  train_seg_loss  val_obj_loss  val_seg_loss
# 0       1          7.1435          3.7162        4.3276        3.9474
# 1       2          1.5841          3.0612        2.3232        3.9109
# 2       3          0.7507          2.8210        1.4792        3.7884
# 3       4          0.4630          2.6337        1.1547        3.7837
# 4       5          0.3264          2.4887        1.0170        3.6370
# ..    ...             ...             ...           ...           ...
# 65     66          0.0407          0.4451        0.7254        2.4168
# 66     67          0.0401          0.4410        0.9040        2.5767
# 67     68          0.0399          0.4320        0.7974        2.4758
# 68     69          0.0412          0.4415        0.6627        2.6237
# 69     70          0.0406          0.4150        0.5662        2.5578
#
# [70 rows x 5 columns]

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
axes[0].plot(df_his['epoch'], df_his['train_obj_loss'], label='train_obj_loss')
axes[0].plot(df_his['epoch'], df_his['val_obj_loss'], label='val_obj_loss')
axes[0].set_title('Object Detection Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].legend()

axes[1].plot(df_his['epoch'], df_his['train_seg_loss'], label='train_seg_loss')
axes[1].plot(df_his['epoch'], df_his['val_seg_loss'], label='val_seg_loss')
axes[1].set_title('Semantic Segmentation Loss')
axes[1].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[1].legend()

# %%
df_his.loc[df_his['val_seg_loss'].argmin()]
# Out:
# epoch             66.0000
# train_obj_loss     0.0407
# train_seg_loss     0.4451
# val_obj_loss       0.7254
# val_seg_loss       2.4168
# Name: 65, dtype: float64
