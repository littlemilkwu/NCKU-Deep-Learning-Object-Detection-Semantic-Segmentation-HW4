# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
PATH_HISTORY = 'logs/training_history_2023-06-18_21:27:21.csv'

# %%
df_his = pd.read_csv(PATH_HISTORY)
df_his
# Out:
#     epoch  train_obj_loss  train_seg_loss  val_obj_loss  val_seg_loss
# 0       1          7.1567          3.1384        3.7729        3.0401
# 1       2          1.4922          2.0985        1.9107        3.1475
# 2       3          0.7150          1.6561        1.2894        3.0040
# 3       4          0.4502          1.3558        1.0597        3.0536
# 4       5          0.3243          1.1755        0.9249        2.9944
# ..    ...             ...             ...           ...           ...
# 65     66          0.0404          0.1817        0.6278        3.2121
# 66     67          0.0410          0.1822        0.5891        3.2677
# 67     68          0.0415          0.1817        0.6442        3.0392
# 68     69          0.0402          0.1782        0.6808        3.3847
# 69     70          0.0393          0.1774        0.6661        3.2471
#
# [70 rows x 5 columns]

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
axes[0].plot(df_his['epoch'], df_his['train_obj_loss'], label='train_obj_loss')
axes[0].plot(df_his['epoch'], df_his['val_obj_loss'], label='val_obj_loss')
axes[0].set_title('Object Detection Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].legend()

axes[1].plot(df_his['epoch'], df_his['train_seg_loss'], label='train_seg_loss')
axes[1].plot(df_his['epoch'], df_his['val_seg_loss'], label='val_seg_loss')
axes[1].set_title('Semantic Segmentation Loss')
axes[1].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[1].legend()

# %%
df_his.loc[df_his['val_seg_loss'].argmin()]
# Out:
# epoch             56.0000
# train_obj_loss     0.0442
# train_seg_loss     0.1986
# val_obj_loss       0.5133
# val_seg_loss       2.9434
# Name: 55, dtype: float64
